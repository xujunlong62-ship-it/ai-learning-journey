# %%
from urllib import response

from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.chat_models import init_chat_model
import os
load_dotenv(dotenv_path=r"D:\SystemData\Python\damoxing\.env", override=True)

model=init_chat_model(
    model='qwen3.5-omni-plus',
    model_provider='openai',
    base_url=os.getenv('dashscope_base_url'),
    api_key=os.getenv('dashscope_api_key'),
)

# %%
response=model.invoke('你是谁')

# %%
print(response)
# Out:
# content='我是 Qwen3.5，是阿里巴巴集团最新推出的通义千问大语言模型。我具备强大的语言理解与生成能力，支持全球 100 多种语言的流畅交互，并能处理复杂逻辑推理、代码全栈开发、长上下文深度分析等任务。无论是解答专业问题、创作内容，还是协助数据分析，我都能提供精准高效的帮助。有什么具体需求，欢迎随时告诉我！' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 87, 'prompt_tokens': 13, 'total_tokens': 100, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': None, 'rejected_prediction_tokens': None, 'text_tokens': 87}, 'prompt_tokens_details': {'audio_tokens': None, 'cache_write_tokens': None, 'cached_tokens': None, 'text_tokens': 13}}, 'model_provider': 'openai', 'model_name': 'qwen3.5-omni-plus', 'system_fingerprint': None, 'id': 'chatcmpl-8f229069-d885-9db9-8dc7-def17bfbea0c', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019f7350-1d4b-72c2-8865-f15f2ff5ef4d-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 13, 'output_tokens': 87, 'total_tokens': 100, 'input_token_details': {}, 'output_token_details': {}}
